# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('data/weather_2012.csv')

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
df.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# ...

# %%
df[df['Temp (C)'] > 32]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 4119  2012-06-20 15:00:00      32.2                19.6           47
# 4120  2012-06-20 16:00:00      32.2                20.0           49
# 4121  2012-06-20 17:00:00      32.3                20.3           49
# 4122  2012-06-20 18:00:00      32.4                19.9           48
# 4142  2012-06-21 14:00:00      32.6                20.4           49
# 4143  2012-06-21 15:00:00      33.0                19.0           44
# 4144  2012-06-21 16:00:00      32.5                17.9           42
# 4145  2012-06-21 17:00:00      32.1                17.9           43
# 4670  2012-07-13 14:00:00      32.1                10.2           26
# 4694  2012-07-14 14:00:00      32.7                15.3           35
# 4695  2012-07-14 15:00:00      33.0                16.8           38
# 4696  2012-07-14 16:00:00      32.9                15.3           35
# 4697  2012-07-14 17:00:00      32.5                16.5           38
# ...

# %%
df.iloc[5]
# Out:
# Date/Time             2012-01-01 05:00:00
# Temp (C)                             -1.4
# Dew Point Temp (C)                   -3.3
# Rel Hum (%)                            87
# Wind Spd (km/h)                         9
# Visibility (km)                       6.4
# Stn Press (kPa)                    101.27
# Weather                               Fog
# Name: 5, dtype: object

# %%
df.iloc[0:5, 0:2]
# Out:
#              Date/Time  Temp (C)
# 0  2012-01-01 00:00:00      -1.8
# 1  2012-01-01 01:00:00      -1.8
# 2  2012-01-01 02:00:00      -1.8
# 3  2012-01-01 03:00:00      -1.5
# 4  2012-01-01 04:00:00      -1.5

# %%
df['Temp (C)'].plot(figsize=(15,6))

# %%
weather_temp = pd.read_csv('data/weather_2012.csv', index_col='Date/Time')

# %%
weather_temp['Temp (C)'].plot(figsize = (15,6))

# %%
apple = pd.read_csv('data/appl_1980_2014.csv')

# %%
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
apple['Date'] = pd.to_datetime(apple['Date'])

x = apple['Date']
y = apple['Adj Close']

# %%
plt.figure(figsize=(15,6))
plt.plot(x,y)
